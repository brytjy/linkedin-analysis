# %%
import pandas as pd
from ast import literal_eval
from collections import Counter
import collections
import matplotlib.pylab as plt
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import operator

# %%
profiles = pd.read_csv("linkedin_profiles.csv")

profiles.experiences = profiles.experiences.apply(literal_eval)
profiles.educations = profiles.educations.apply(literal_eval)
profiles.licenses_and_certificates = profiles.licenses_and_certificates.apply(literal_eval)
profiles.skills = profiles.skills.apply(literal_eval)

# %%
profiles.head()
# Out:
#            name                                           headline   location  \
# 0  Nikita Gupta  Data Analyst at TBWA\The Disruption Company | ...  Singapore
# 1     Jayden Ho          Senior Data Analyst at Publicis Singapore  Singapore
# 2   Timothy Ong                      Senior Data Analyst at Shopee  Singapore
# 3        Zi Lin                            Data Analyst at GovTech  Singapore
# 4   Minghao Liu                     Data Analyst at Energy Aspects  Singapore
#
#   no_of_connections                                              about  \
# 0  500+ connections  I am currently at TBWA,Singapore helping adver...
# 1   339 connections  Uncovering insights and trends for the consume...
# 2   463 connections  Timothy has a huge passion for data analytics....
# 3   147 connections  • Lead a team of 20+ patrol officers at a Neig...
# 4   307 connections                          mining and deep learning.
#
#                                          experiences  \
# 0  [{'title': 'Data Analyst', 'company': 'TBWA\ G...
# 1  [{'title': 'Senior Data Analyst, Strategy', 'c...
# 2  [{'title': 'Senior Data Analyst', 'company': '...
# 3  [{'title': 'Data Analyst, Data Science & Artif...
# 4  [{'title': 'Data Analyst', 'company': 'Energy ...
#
#                                           educations  \
# 0  [{'school': 'Singapore Management University',...
# 1  [{'school': 'RMIT University', 'type': 'Bachel...
# 2  [{'school': 'Singapore Management University',...
# 3  [{'school': 'Harvard University', 'type': 'Mas...
# 4  [{'school': 'National University of Singapore'...
#
#                            licenses_and_certificates  \
# 0  [{'name': 'DoubleClick Campaign Manager Fundam...
# 1  [{'name': 'Intro to SQL for Data Science', 'pr...
# 2  [{'name': 'Six Sigma Green Belt', 'provider': ...
# 3  [{'name': 'Exploratory Data Analysis', 'provid...
# 4  [{'name': '计算导论与C语言基础', 'provider': 'Coursera'...
#
#                                               skills
# 0  [Databases, Business Analysis, Data Structures...
# 1  [Business Analytics, Data Visualization, Socia...
# 2                                                 []
# 3  [R, Investigation, Statistical Data Analysis, ...
# 4  [SQL, R, Python, Data Analysis, Data Mining, M...

# %% [markdown]
# ### Total Number of Profiles

# %%
print(len(profiles))
# Out:
# 534

# %% [markdown]
# ### Connections Distribution

# %%
no_of_connections_raw = profiles["no_of_connections"].tolist()

# %%
def remove_connections_word(text):
    text = text.replace(' connections', '')
    text = text.replace(' connection', '')
    text = text.replace('500+', str(501))
    return text

# %%
no_of_connections = [remove_connections_word(item) for item in no_of_connections_raw]

# %%
no_of_connections[:5]
# Out:
# ['501', '339', '463', '147', '307']

# %%
def convert_to_range(connection):
    if int(connection) <= 50:
        return "0-50"
    elif int(connection) > 50 and int(connection) <= 100:
        return "51-100"
    elif int(connection) > 100 and int(connection) <= 150:
        return "101-150"
    elif int(connection) > 150 and int(connection) <= 200:
        return "151-200"
    elif int(connection) > 200 and int(connection) <= 250:
        return "201-250"
    elif int(connection) > 250 and int(connection) <= 300:
        return "251-300"
    elif int(connection) > 300 and int(connection) <= 350:
        return "301-350"
    elif int(connection) > 350 and int(connection) <= 400:
        return "351-400"
    elif int(connection) > 400 and int(connection) <= 450:
        return "401-450"
    elif int(connection) > 450 and int(connection) <= 500:
        return "451-500"
    else:
        return "501+"

# %%
no_of_connections_range = [convert_to_range(item) for item in no_of_connections]

# %%
no_of_connections_range[:5]
# Out:
# ['501+', '301-350', '451-500', '101-150', '301-350']

# %%
connections_count = Counter(no_of_connections_range)

# %%
connections_count
# Out:
# Counter({'501+': 275,
#          '301-350': 26,
#          '451-500': 20,
#          '101-150': 26,
#          '401-450': 20,
#          '251-300': 25,
#          '151-200': 41,
#          '351-400': 35,
#          '51-100': 25,
#          '201-250': 27,
#          '0-50': 14})

# %%
connections_count_list = sorted(connections_count.items())
x, y = zip(*connections_count_list)

# %%
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(x))
    # set the style of the axes and the text color
    plt.rcParams['axes.edgecolor']='#333F4B'
    plt.rcParams['axes.linewidth']=0.8
    plt.rcParams['xtick.color']='#333F4B'
    plt.rcParams['ytick.color']='#333F4B'
    plt.rcParams['text.color']='#333F4B'
    plt.rcParams['figure.figsize'] = 10, 5
    plt.bar(index, y)
    plt.xlabel('Number of Connections', fontsize=10)
    plt.xticks(index, x, fontsize=10, rotation=30)
    plt.title('Connections Distribution')
    plt.show()

# %%
plot_bar_x()

# %% [markdown]
# ### WordCloud on Headline and About Section

# %%
# COMBINE ALL HEADLINE AND ABOUT SECTIONS INTO ONE STRING
headline_combined = " ".join(str(headline) for headline in profiles.headline)
about_combined = " ".join(str(about) for about in profiles.about)
print ("There are {} words in the combination of all headline sections.".format(len(headline_combined)))
print ("There are {} words in the combination of all about sections.".format(len(about_combined)))

combined_text = headline_combined + " " + about_combined
# Out:
# There are 21637 words in the combination of all headline sections.
# There are 321850 words in the combination of all about sections.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["Singapore", "data", "analyst", "scientist", "analysis", "analyst", "science", "machine", "learning", "analytic", "analytics"])

# %%
# Display the generated image:
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=100, background_color="white").generate(combined_text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Education Distribution

# %%
all_educations = profiles['educations']

# %%
all_schools = []
all_types = []
all_courses = []

for educations in all_educations:
    for education in educations:
        try:
            all_schools.append(education['school'])
        except:
            all_schools.append("Nil")
        try:
            all_types.append(education['type'])
        except:
            all_types.append("Nil")
        try:
            all_courses.append(education['course'])
        except:
            all_courses.append("Nil")

# %%
all_schools_count = Counter(all_schools)
all_schools_count_sorted = sorted(all_schools_count.items(), key=lambda kv: kv[1])

# %%
all_schools_count_sorted
# Out:
# [('Jaypee Institute of Information Technology', 1),
#  ('Technische Universität München', 1),
#  ('Harvard University', 1),
#  ('HBX | Harvard Business School', 1),
#  ('Nanyang Junior college', 1),
#  ("Xi'an Jiaotong University", 1),
#  ('Stockholm School of Economics', 1),
#  ('Higher School of Economics', 1),
#  ('IEDC-Poslovna šola Bled', 1),
#  ('The University of Queensland', 1),
#  ('HEC School of Management / HEC Paris', 1),
#  ('London School of Economics and Political Science', 1),
#  ('Melbourne Business School', 1),
#  ('Raffles Junior College, Singapore', 1),
#  ('ZHAW School of Management and Law', 1),
#  ('National Institute of Education, Singapore', 1),
#  ('University of Leeds', 1),
#  ('ACCA', 1),
#  ('Oxford Brookes University', 1),
#  ('LNMIIT', 1),
#  ('Hogeschool Inholland / Inholland University of Applied Sciences', 1),
#  ('Anglo Chinese School (Independent)', 1),
#  ('MITx on edX', 1),
#  ('SMA Santo Aloysius Bandung', 1),
#  ('Carnegie Mellon University - Tepper School of Business', 1),
#  ('Renmin University of China', 1),
#  ('Innova Junior College', 1),
#  ('Donghua University', 1),
#  ('Shanghai International Studies University', 1),
#  ('Royal Melbourne Institute of Technology ( RMIT)', 1),
#  ('The University of Sheffield', 1),
#  ('Vivekanandha Institute', 1),
#  ('University of Melbourne - Melbourne Business School', 1),
#  ('St. Andrew’s Junior College', 1),
#  ('Suzhou University', 1),
#  ('Universitas Katolik Indonesia Atma Jaya', 1),
#  ('Lund University School of Economics and Management', 1),
#  ('toulouse business school', 1),
#  ('Great Lakes Institute of Management', 1),
#  ('Amity Business School', 1),
#  ('Universitas Gadjah Mada (UGM)', 1),
#  ('Seth Jai Parkash Mukand Lal Inst. of Engineering & Technology', 1),
#  ('Jawahar navodaya vidhalya', 1),
#  ('Murdoch University', 1),
#  ('Pasir Ris Secondary School', 1),
#  ('Punjab Technical University', 1),
#  ('Methodist-2 Senior High School', 1),
#  ('River Valley High School', 1),
#  ('C V raman college of engineering', 1),
#  ('Sun Yat-Sen University', 1),
#  ('University of Central Florida', 1),
#  ('Rosyth Sch', 1),
#  ('University of Oregon', 1),
#  ('Anderson Secondary School', 1),
#  ('Korea University', 1),
#  ('Thiagarajar College of Engineering', 1),
#  ('Class XII (T.N State Board) Mahatma Montessori Matriculation Hr Sec School',
#   1),
#  ('Mahatma Montessori Matriculation Hr Sec School', 1),
#  ('Fr.C.R.C.E. (Engineering College)', 1),
#  ('Indira Institute of Engineering and Technology,Anna University ,Chennai Area,India',
#   1),
#  ('Bhaktavatsalam Vidyashram', 1),
#  ('University at Buffalo', 1),
#  ('Singapore Institute of Management', 1),
#  ('Ludwig-Maximilians Universität München', 1),
#  ('Nitte Meenakshi Institue of Technology', 1),
#  ('Vikas Vidyalayam', 1),
#  ('Nalanda Talent School', 1),
#  ('Yonsei University', 1),
#  ('M.P.Birla Institute of Management', 1),
#  ('R.L.Jalappa Institute of Technology', 1),
#  ('The ICFAI University, Tripura', 1),
#  ('Manipal University', 1),
#  ('SCT College of Engineering', 1),
#  ('St.Thomas Residential School', 1),
#  ('Annamalai University, India', 1),
#  ('National Sun Yat-sen University', 1),
#  ('CMR Institute Of Management Studies', 1),
#  ('Montfort Secondary School', 1),
#  ('UNSW', 1),
#  ('Garden International School', 1),
#  ('IE University', 1),
#  ('University of Southern California - Marshall School of Business', 1),
#  ('Soochow University (CN)', 1),
#  ("King's College London", 1),
#  ('University of San Carlos', 1),
#  ('Nanjing University of Posts and Telecommunications', 1),
#  ('National University of Defense Technology', 1),
#  ('Kerala University, Thiruvananthapuram', 1),
#  ('NYU Tandon School of Engineering', 1),
#  ('Singapore Chinese Girls School', 1),
#  ('Harvard Extension School', 1),
#  ('University of California, Santa Cruz', 1),
#  ('Yale-NUS College', 1),
#  ("UWC Adriatic - Collegio del Mondo Unito dell'Adriatico O.N.L.U.S.", 1),
#  ('Sekolah Menengah Kebangsaan Ledang (Ledang National Secondary School)', 1),
#  ('Foon Yew High School Johor Bahru', 1),
#  ('华侨大学', 1),
#  ('Universität Mannheim', 1),
#  ('Universität Bern', 1),
#  ('University of Oulu', 1),
#  ('Devan Nair Institute for Employment & Employability', 1),
#  ('The University of Western Australia', 1),
#  ('Ahmad Ibrahim Secondary School', 1),
#  ('cotton college', 1),
#  ('IDC Herzliya', 1),
#  ('Coding Girls', 1),
#  ('DataGirls', 1),
#  ('Ulyanovsk State University', 1),
#  ('Catholic Junior College, Singapore', 1),
#  ("St. Joseph's Institution, Singapore", 1),
#  ('Kongu Engineering College', 1),
#  ('Serangoon Junior College', 1),
#  ("St Joseph's Institution", 1),
#  ('Jawaharlal Nehru University', 1),
#  ('Delhi University', 1),
#  ('Carmel School', 1),
#  ('Institute of Actuaries of India,Mumbai', 1),
#  ('Ecole Hôtelière de Lausanne', 1),
#  ('Gymase August Piccard', 1),
#  ('Northeast Normal University', 1),
#  ('Tembusu College', 1),
#  ('Residential College 4 - University Town College Program', 1),
#  ('The University of Connecticut', 1),
#  ('Soundararaja Vidyalaya', 1),
#  ('Geylang Methodist School (Secondary)', 1),
#  ('NEOMA Business School', 1),
#  ("Saint Joseph's Institution", 1),
#  ('Central Institute Of Plastics Engineering and Technology', 1),
#  ('James Cook University', 1),
#  ('University of Rajasthan', 1),
#  ('University of Pittsburgh', 1),
#  ('Beijing Foreign Studies University', 1),
#  ('BUNDELKHAND INSTITUTE OF ENGINEERING AND TECHNOLOGY, JHANSI', 1),
#  ('National Institute of Science and Technology (NIST), Berhampur', 1),
#  ('Jurong Junior College', 1),
#  ('Wayne State University', 1),
#  ('Hwa Chong Instituition', 1),
#  ('University of Chinese Academy of Sciences', 1),
#  ('BTLIT, Bangalore', 1),
#  ('TMS, Chickmagalur', 1),
#  ('Guanghua School of Management', 1),
#  ('SIM Global Education', 1),
#  ('Insper', 1),
#  ('Erasmus University Rotterdam', 1),
#  ('Anglo-Chinese School (Independent)', 1),
#  ('Catholic Theological Institute of Singapore', 1),
#  ('GreyAtom School of Data Science', 1),
#  ('KJ Somaiya College of Engineering, Vidyavihar', 1),
#  ('Nanjing University of Science and Technology', 1),
#  ('SHRI Academy', 1),
#  ("Crescent Girls' School", 1),
#  ('Mody Institute of Technology & Science, Sikar', 1),
#  ('St Andrews JC', 1),
#  ('University of California, Santa Barbara', 1),
#  ("Methodist Girls' School", 1),
#  ('Universitas Surabaya (UBAYA)', 1),
#  ('University of Malaya', 1),
#  ('National University of Malaysia', 1),
#  ('Aalto-yliopisto', 1),
#  ('Shanghai Jiao Tong University', 1),
#  ('Arcada University of Applied Science', 1),
#  ('Mount Royal College', 1),
#  ('University of Victoria', 1),
#  ('Management Development Institute of Singapore', 1),
#  ('Coursera platform', 1),
#  ('Université Paris Dauphine', 1),
#  ('Universiti Putra Malaysia', 1),
#  ('The Odin Project', 1),
#  ('Central South University', 1),
#  ('Anglo Chinese School Independent', 1),
#  ('Singapore University of Technology and Design', 1),
#  ('Saint Andrew’s Secondary School', 1),
#  ('Griffiths Primary School', 1),
#  ('University of Virginia', 1),
#  ('High School for Gifted Students', 1),
#  ('UWC South East Asia', 1),
#  ('Narsee Monjee Institute of Management Studies, Mumbai', 1),
#  ('Jinan University', 1),
#  ('Université Grenoble Alpes', 1),
#  ('universite de Haute-Alsace', 1),
#  ("Holy Innocents' High School", 1),
#  ('Max Planck Institute for Mathematics in the Natural Sciences', 1),
#  ('Society of Actuaries', 1),
#  ('Nowrosjee Wadia College', 1),
#  ('New English School Ramanbaug', 1),
#  ('Manipal Institute of Technology', 1),
#  ('Sri venkateswara college of engineering', 1),
#  ('Sri Sathya Sai Higher Secondary School', 1),
#  ('Sir Siva Swami Kalalaya', 1),
#  ('Rajagiri School Of Engineering and Technology', 1),
#  ('De La Salle University', 1),
#  ('Institute of Systems Science, National University of Singapore', 1),
#  ('Shandong University of Finance and Economics', 1),
#  ('University of Duisburg-Essen', 1),
#  ('Saint-Petersburg State Univesity', 1),
#  ('Data Science Retreat Berlin', 1),
#  ('DigiPen Institute of Technology', 1),
#  ('Catholic High School', 1),
#  ('Hwa Chong Institution (Junior College)', 1),
#  ('The University of Glasgow', 1),
#  ('Singapore Institute of Technology', 1),
#  ('Linköping University', 1),
#  ('Nanyang Technological University (NTU), Singapore', 1),
#  ('Peking University (PKU), China', 1),
#  ('Jilin University, China', 1),
#  ('Yishun Junior College', 1),
#  ('Shandong University', 1),
#  ('University of Warwick', 1),
#  ('Rajiv Gandhi Prodyogiki Vishwavidyalaya', 1),
#  ('Open Source Society University', 1),
#  ('The University of British Columbia', 1),
#  ('Data Science @ Harvard University (Online Course)', 1),
#  ('VJTI', 1),
#  ('Bala Vidya Mandir Senior Secondary School', 1),
#  ('PES Institute Of technology', 1),
#  ('University of California, Davis', 1),
#  ('Nitte Meenakshi Institute Of Technology', 1),
#  ('University of North Carolina at Chapel Hill', 1),
#  ('Hwa Chong Institution (College)', 1),
#  ('Hwa Chong Institution (High School)', 1),
#  ("Université d'Orléans", 1),
#  ('Academia de Studii Economice din București', 1),
#  ('SASTRA University', 1),
#  ('Sri Sivasubramaniya Nadar College Of Engineering', 1),
#  ('City Montessori School', 1),
#  ('Princeton University', 1),
#  ('Vivekananda Kendra Vidyalaya matriculation higher secondary school', 1),
#  ('NIT, Rourkela, India', 1),
#  ('MINES ParisTech', 1),
#  ('Lycée Champollion Grenoble', 1),
#  ('Cité scolaire internationale of Grenoble', 1),
#  ('Albert Einstein Gymnasium', 1),
#  ('EPFL (École polytechnique fédérale de Lausanne)', 1),
#  ('Royal Holloway, University of London', 1),
#  ('Coursera', 1),
#  ('University of Surrey', 1),
#  ('Samuel Whitbread', 1),
#  ('University of Miami', 1),
#  ('Kurukshetra University', 1),
#  ('University of Information Technology', 1),
#  ('FPT International Consulting Center (FITC)', 1),
#  ('University of Leuven', 1),
#  ('LASALLE College of the Arts', 1),
#  ('University of Johannesburg', 1),
#  ('Birla Institute of Technology and Science', 1),
#  ('Institute of Technology and Management', 1),
#  ("St. Anthony's Convent School", 1),
#  ("St. Xavier's School", 1),
#  ('The University of Western Ontario', 1),
#  ('Cherkasy National University', 1),
#  ('Xiamen University', 1),
#  ('National ChengChi University', 1),
#  ('Tamang University', 1),
#  ('Purdue University', 1),
#  ('Supélec', 1),
#  ('Lycée Faidherbe', 1),
#  ('Buckinghamshire New University', 1),
#  ('Bratsk State University', 1),
#  ('INDIRA GANDHI DELHI TECHNICAL UNIVERSITY FOR WOMEN', 1),
#  ('Delhi Public School - R. K. Puram', 1),
#  ('Ryan International School,Vasant Kunj', 1),
#  ('The American School in Japan', 1),
#  ('College of Engineering Pune', 1),
#  ('St Vincents High School and Junior College , Pune', 1),
#  ('University of Wisconsin-Madison', 1),
#  ('National Institute of Technology, Karnataka', 1),
#  ('Fudan University', 1),
#  ('University of California, San Diego', 1),
#  ('Andhra University, Visakhapatnam', 1),
#  ('National Law University, Jodhpur', 1),
#  ('University of Antwerp', 1),
#  ('Bahçeşehir Üniversitesi', 1),
#  ('Istanbul Technical University', 1),
#  ("Queen's University", 1),
#  ('School of Management Studies,CUSAT', 1),
#  ('School of Technology and Applied Sciences', 1),
#  ('Vidyodaya School', 1),
#  ('新加坡南洋理工大学', 1),
#  ('Dalian University of Technology', 1),
#  ('University of Waterloo', 1),
#  ('Sathyabama University', 1),
#  ('MIT Sloan School of Management', 1),
#  ('Ghent University', 1),
#  ('Universiteit Gent', 1),
#  ('Raffles Institution (Junior College)', 1),
#  ('Amrita School of Engineering, Amritapuri', 1),
#  ('Chinmaya Vidyalaya, Kolazhy', 1),
#  ('London School of Hygiene and Tropical Medicine, U. of London', 1),
#  ("St Joseph's Institution (SJI)", 1),
#  ('Lycée Jean Perrin (Lyon 9ème)', 1),
#  ('Birla Institute of Technology and Science, Pilani', 1),
#  ('Loyola School', 1),
#  ('Tadcaster Grammar School', 1),
#  ('The Data Incubator', 1),
#  ('Drexel University', 1),
#  ('University of Calcutta', 1),
#  ('Rudrapur Radhaballav High School', 1),
#  ('Independent Coursework', 1),
#  ('Mahatma Gandhi University', 1),
#  ('School of EEE, NTU', 1),
#  ('maharshi markandeshwar university', 1),
#  ('asha Modern School', 1),
#  ('Maharishi Vidya Mandir', 1),
#  ('Vels Vidyashram', 1),
#  ('Pondicherry University', 1),
#  ('University of Shanghai for Science and Technology', 1),
#  ('Ramakrishna Mission Matric Higher Sec School', 1),
#  ('Technische Universiteit Eindhoven', 1),
#  ('Cornell University Graduate School', 1),
#  ('Delhi University, Netaji Subhas Institute of Technology', 1),
#  ('Delhi Public School , R.K. Puram', 1),
#  ('Budapesti Mûszaki és Gazdaságtudományi Egyetem / Technical University of Budapest',
#   1),
#  ('Guru Tegh Bahudur Institute of Techology', 1),
#  ('Delhi Public School - Dwarka', 1),
#  ('Huazhong University of Science and Technology', 1),
#  ('Universiti Malaysia Sarawak', 1),
#  ('Wesleyan University', 1),
#  ('Waseda University', 1),
#  ('Jaypee Institute of Information Technology, Noida', 1),
#  ('Curtin University of Technology', 1),
#  ('Foon Yew High School', 1),
#  ('Central University of Finance and Economics', 1),
#  ('IMI University Centre Luzern', 1),
#  ('Temasek JC', 1),
#  ('Chung Cheng High School (Main)', 1),
#  ('Xuzhou No. 1 Middle School', 1),
#  ('Anglo-Chinese School (Ipoh)', 1),
#  ('上海交通大学', 1),
#  ('University of Nottingham', 1),
#  ('Indian Statistical Institute(SQC & OR)', 1),
#  ('Korea Advanced Institute of Science and Technology', 1),
#  ('Anglo Chinese Junior College', 1),
#  ('PhD in Industrial Engineering, Purdue University', 1),
#  ('Executive Development Center, Bradley University', 1),
#  ('University of Cincinnati', 1),
#  ('Illinois Institute of Technology', 1),
#  ('Lakshmi Matriculation School,Trichy', 1),
#  ('nss engineering college', 1),
#  ('Tampere University of Technology', 1),
#  ('Københavns Universitet', 1),
#  ('Télécom ParisTech', 1),
#  ('Paris-Sud University (Paris XI)', 1),
#  ('Indian Institute of Technology, Hyderabad', 1),
#  ('Sri Venkateswara University', 1),
#  ('Warsaw School of Economics', 1),
#  ('Victoria Integrated Programme', 1),
#  ('Université Laval', 1),
#  ('Kuen Cheng High School', 1),
#  ('National Institute of Technology Durgapur', 1),
#  ('Kendriya Vidyalaya No.1, Tirupati', 1),
#  ('Indian Institute of Technology, Roorkee', 1),
#  ('Universidad de Chile', 1),
#  ('Universidad Católica de Valparaíso', 1),
#  ('Ecole polytechnique fédérale de Lausanne', 1),
#  ('South China University of Technology', 1),
#  ('Nanyang Business School, Nanyang Technological University', 1),
#  ('School of Electrical and Electronics Engineering, Nanyang Technological University',
#   1),
#  ('Heriot-Watt University', 1),
#  ('Ho Chi Minh Technology University - DH Bach Khoa TPHCM', 1),
#  ('Le Hong Phong High School for the Gifted, top High School in Ho Chi Minh City',
#   1),
#  ('Town Higher Secondary School', 1),
#  ('Govind Ballabh Pant Krishi Evam Praudyogik Vishwavidyalaya', 1),
#  ('PES Institute of Technology', 1),
#  ('Seedling Public School', 1),
#  ('Chalmers University of Technology', 1),
#  ('Newcastle University, UK. Singapore Institute Of Technology', 1),
#  ('University of Technology HCMC, Vietnam', 1),
#  ('Harvard Business School', 1),
#  ('Stanford University (Coursera)', 1),
#  ('Ruhr-Universität Bochum', 1),
#  ('National Institute of Technology, Trichy', 1),
#  ('Delhi Public School, Bokaro', 1),
#  ('Institute of Automation, CAS', 1),
#  ('Beijing University of Post and Telecommunications', 1),
#  ('Northwestern Polytechnic University', 1),
#  ('National Cheng Kung University', 1),
#  ('University of Mumbai', 1),
#  ('Northwestern University', 1),
#  ('Delhi College of Engineering', 1),
#  ('DL DAV Model school', 1),
#  ('ENSAE Paris', 1),
#  ('Université Paris Diderot', 1),
#  ('University of Wales', 1),
#  ('PES University', 1),
#  ('University of Moratuwa', 1),
#  ('Jaffna Hindu College', 1),
#  ('SMU Institute of Innovation & Entrepreneurship', 1),
#  ('Wuhan University', 1),
#  ('Nantong Middle School', 1),
#  ('SreeNidhi Institute of Science and Technology', 1),
#  ('Ateneo de Manila University', 1),
#  ('University of Technology, Malaysia', 1),
#  ('KJ Somaiya College Of Engineering, Mumbai University', 1),
#  ('deeplearning.ai', 1),
#  ('University', 1),
#  ('CentraleSupelec', 1),
#  ('NUS High School of Mathematics & Science', 1),
#  ('Ecole polytechnique', 1),
#  ('Collège des Ingénieurs', 1),
#  ('National University of Singapore (ISS)', 1),
#  ('Holy Child School', 2),
#  ('Hwa Chong Junior College', 2),
#  ("Raffles Girls' School", 2),
#  ('Pioneer Junior College', 2),
#  ('East China Normal University', 2),
#  ('CFA Institute', 2),
#  ("Saint Andrew's Junior College", 2),
#  ('The Chinese High School', 2),
#  ('The LNM Institute of Information Technology', 2),
#  ('Carnegie Mellon University', 2),
#  ('Nanyang Business School, NTU', 2),
#  ('SIM University', 2),
#  ('Guru Gobind Singh Indraprastha University', 2),
#  ('The University of Edinburgh', 2),
#  ('Lanzhou University', 2),
#  ('Multimedia University', 2),
#  ('Copenhagen Business School', 2),
#  ('Imperial College Business School', 2),
#  ('Eidgenössische Technische Hochschule Zürich', 2),
#  ('National Chengchi University', 2),
#  ('Universität Ulm', 2),
#  ('Beihang University', 2),
#  ('University of Newcastle-upon-Tyne', 2),
#  ('University of Indonesia', 2),
#  ('Annamalai University', 2),
#  ('Charles University in Prague', 2),
#  ('Uppsala University', 2),
#  ('University of Southern California', 2),
#  ('PSB Academy', 2),
#  ('Zhejiang University', 2),
#  ('Hackwagon Academy', 2),
#  ('freeCodeCamp', 2),
#  ('Technical University Munich', 2),
#  ('University of Birmingham', 2),
#  ('Kyungpook National University', 2),
#  ('Hanyang University', 2),
#  ('University of Newcastle', 2),
#  ('Smartly School of Business', 2),
#  ('Southwestern University of Finance and Economics', 2),
#  ('Columbia University in the City of New York', 2),
#  ('University of the Philippines', 2),
#  ('University of London International Programmes', 2),
#  ('Singapore University of Social Sciences (SUSS)', 2),
#  ("National Technical University of Ukraine 'Kyiv Polytechnic Institute'", 2),
#  ("Nanyang Girls' High School", 2),
#  ('Jaypee Institute Of Information Technology', 2),
#  ('University of Toronto', 2),
#  ('University of Pune', 2),
#  ('Northeastern University (CN)', 2),
#  ('Yale University', 2),
#  ('Macquarie University', 2),
#  ('Nanyang Academy of Fine Arts', 2),
#  ('University of Oxford', 2),
#  ('Indian School of Business', 2),
#  ('University of Southampton', 2),
#  ('Università degli Studi di Roma Tre', 2),
#  ('The Hong Kong Polytechnic University', 2),
#  ('Nanjing University', 2),
#  ('INSEAD', 2),
#  ('PSG College of Technology', 2),
#  ('National Taiwan University', 2),
#  ('University of the Witwatersrand', 2),
#  ('Indian Institute of Technology, Delhi', 2),
#  ('Kendriya Vidyalaya', 2),
#  ('University of Electronic Science and Technology', 2),
#  ('University of Pennsylvania', 2),
#  ('Indian Institute of Technology, Kanpur', 2),
#  ('China Medical University', 2),
#  ('Shanmugha Arts, Science, Technology and Research Academy', 2),
#  ('KTH Royal Institute of Technology', 2),
#  ('University of Science and Technology of China', 2),
#  ('Simplilearn Alumni', 2),
#  ('Johns Hopkins University', 2),
#  ('Beijing University of Posts and Telecommunications', 2),
#  ('Yanshan University', 2),
#  ('筑波大学 / University of Tsukuba', 2),
#  ('Université Pierre et Marie Curie (Paris VI)', 2),
#  ('University of London', 3),
#  ('Peking University', 3),
#  ('Republic Polytechnic', 3),
#  ('The University of Hong Kong', 3),
#  ('Visvesvaraya Technological University', 3),
#  ('Nanyang Junior College', 3),
#  ('City University of Hong Kong', 3),
#  ('Catholic Junior College', 3),
#  ('Dunman High School', 3),
#  ('Hwa Chong Institution', 3),
#  ('University of Cambridge', 3),
#  ('Dalian Maritime University', 3),
#  ('Indian Institute of Technology, Madras', 3),
#  ('University of Madras', 3),
#  ('Université Lumière (Lyon II)', 3),
#  ('Indian Institute of Technology, Bombay', 3),
#  ('University of Melbourne', 4),
#  ('Anglo-Chinese Junior College', 4),
#  ('Singapore University of Social Sciences', 4),
#  ('NUS Masters of Science in Business Analytics (MSBA)', 4),
#  ('SRM University', 4),
#  ('Anderson Junior College', 4),
#  ('University of California, Los Angeles', 4),
#  ('Monash University', 4),
#  ('Harbin Institute of Technology', 4),
#  ('The Chinese University of Hong Kong', 4),
#  ('Massachusetts Institute of Technology', 4),
#  ('Nankai University', 4),
#  ('University of Adelaide', 4),
#  ('Nil', 5),
#  ('Imperial College London', 5),
#  ('Temasek Junior College', 5),
#  ('Raffles Junior College', 5),
#  ('RMIT University', 6),
#  ('Meridian Junior College', 6),
#  ('The Hong Kong University of Science and Technology', 6),
#  ('National Junior College', 6),
#  ('The Australian National University', 6),
#  ('Sri Sathya Sai Institute of Higher Learning', 6),
#  ('University of California, Berkeley', 7),
#  ('The London School of Economics and Political Science (LSE)', 8),
#  ('Raffles Institution', 8),
#  ('Singapore University of Technology and Design (SUTD)', 8),
#  ('NUS Overseas Colleges', 8),
#  ('Georgia Institute of Technology', 8),
#  ('Victoria Junior College', 8),
#  ('University of Illinois at Urbana-Champaign', 9),
#  ('National University of Singapore / NUS', 10),
#  ('Stanford University', 10),
#  ('Ngee Ann Polytechnic', 11),
#  ('Udacity', 11),
#  ('Anna University', 12),
#  ('Temasek Polytechnic', 16),
#  ('General Assembly', 17),
#  ('Nanyang Polytechnic', 19),
#  ('Singapore Polytechnic', 19),
#  ('Singapore Management University', 68),
#  ('Nanyang Technological University', 102),
#  ('National University of Singapore', 300)]

# %%
schools = []
schools_count = []
for item in all_schools_count_sorted:
    if item[1] > 5:
        schools.append(item[0])
        schools_count.append(item[1])

# %%
print(schools[:5])
print(schools_count[:5])
# Out:
# ['RMIT University', 'Meridian Junior College', 'The Hong Kong University of Science and Technology', 'National Junior College', 'The Australian National University']
# [6, 6, 6, 6, 6]

# %%
def plot_bar_schools():
    # this is for plotting purpose
    index = np.arange(len(schools))
    # set the style of the axes and the text color
    plt.rcParams['axes.edgecolor']='#333F4B'
    plt.rcParams['axes.linewidth']=0.8
    plt.rcParams['xtick.color']='#333F4B'
    plt.rcParams['ytick.color']='#333F4B'
    plt.rcParams['text.color']='#333F4B'
    plt.rcParams['figure.figsize'] = 15, 5
    plt.bar(index, schools_count)
    plt.xlabel('Schools', fontsize=10)
    plt.xticks(index, schools, fontsize=8, rotation=90)
    plt.title('Schools Distribution')
    plt.show()

# %%
plot_bar_schools()

# %% [markdown]
# ### Skills Distribution

# %%
all_skills = profiles['skills']

# %%
all_skills[:5]
# Out:
# 0    [Databases, Business Analysis, Data Structures...
# 1    [Business Analytics, Data Visualization, Socia...
# 2                                                   []
# 3    [R, Investigation, Statistical Data Analysis, ...
# 4    [SQL, R, Python, Data Analysis, Data Mining, M...
# Name: skills, dtype: object

# %%
all_skills_expanded = []
for skills in all_skills:
    for skill in skills:
        all_skills_expanded.append(skill)
        
all_skills_expanded[:10]
# Out:
# ['Databases',
#  'Business Analysis',
#  'Data Structures',
#  'Analytical Skills',
#  'Project Management',
#  'Event Management',
#  'Data Analysis',
#  'Market Analysis',
#  'Management Consulting',
#  'Web Analytics']

# %%
skills_count = Counter(all_skills_expanded)

# %%
skills_count_sorted = sorted(skills_count.items(), key=lambda kv: kv[1])

# %%
skills = []
skills_count = []
for item in skills_count_sorted:
    if item[1] > 30:
        skills.append(item[0])
        skills_count.append(item[1])

# %%
print(skills[:5])
print(skills_count[:5])
# Out:
# ['Natural Language Processing (NLP)', 'Time Series Analysis', 'Requirements Analysis', 'Strategy', 'Customer Service']
# [31, 31, 32, 32, 32]

# %%
def plot_bar_skills():
    # this is for plotting purpose
    index = np.arange(len(skills))
    # set the style of the axes and the text color
    plt.rcParams['axes.edgecolor']='#333F4B'
    plt.rcParams['axes.linewidth']=0.8
    plt.rcParams['xtick.color']='#333F4B'
    plt.rcParams['ytick.color']='#333F4B'
    plt.rcParams['text.color']='#333F4B'
    plt.rcParams['figure.figsize'] = 15, 5
    plt.bar(index, skills_count)
    plt.xlabel('Skills', fontsize=10)
    plt.xticks(index, skills, fontsize=8, rotation=90)
    plt.title('Skills Distribution')
    plt.show()

# %%
plot_bar_skills()
